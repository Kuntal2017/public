# %% [markdown]
# ## Seaborn

# %% [markdown]
# #### Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

#tips(restaurant bill tip) dataset is already included in seaborn library

# %%
df.head()
#only tip is dependent feature
#total_bill,sex,smoker,day,time,size are independent feature
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#jointplot. Seaborn's jointplot displays a relationship between 2 variables
#(bivariate) as well as 1D profiles (univariate) in the margins. 
#This plot is a convenience class that wraps JointGrid.

# %%
#bivariate analysis 
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')
#it is drawing prbabality density function(on histogram on side and on top)
#and also regression line is also drawn from best fit(through points)

# %% [markdown]
# ### Pairplot

# %% [markdown]
# Pair Plots are a really simple (one-line-of-code simple!) way to visualize relationships between each variable. It produces a matrix of relationships between each variable in your data for an instant examination of our data. It can also be a great jumping off point for determining types of regression analysis to use.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='day')

# %%
#Seaborn distplot lets you show a histogram with a line on it.
#This can be shown in all kinds of variations. 
#We use seaborn in combination with matplotlib, the Python plotting module. ...
#The distplot() function combines the matplotlib hist function with the 
#seaborn kdeplot() and rugplot() functions.

# %%
sns.distplot(df['tip'])

# %%
 sns.distplot(df['tip'],kde=False,bins=10)

# %%
#Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. 
#It is used for non-parametric analysis.

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
#countplot= Show the counts of observations in each categorical bin using bars.
sns.countplot('smoker',data=df)

# %%
sns.countplot('day',data = df)
#we only mention one axis either x or y and other axis is count

# %%
sns.countplot(y='sex',data=df)
#horizontal plot

# %%
#barplot (we mention both x and y axis )
#Show point estimates and confidence intervals as rectangular bars.
sns.barplot(x='total_bill',y='sex',data=df)

# %%
sns.barplot(y='total_bill',x='sex',data=df)

# %%
#boxplot (five number summary)
sns.boxplot('smoker','total_bill',data=df)
#here dots represent outliers

# %%
sns.boxplot(x='day',y='total_bill',data = df,palette='rainbow')

# %%
sns.boxplot(x='total_bill',y='day',hue="smoker",data=df)
#hue= smoker it means it will create differrent diagrams based on smoker(yes/no)

# %%
#violinplot #Draw a combination of boxplot and kernel density estimate.
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')

# %%
#lets try with iris dataset

# %%
df1 = sns.load_dataset('iris')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.countplot('species',data=df1)

# %%
df1.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(data=df1)

# %%
sns.boxplot('petal_length','species',data=df1)
